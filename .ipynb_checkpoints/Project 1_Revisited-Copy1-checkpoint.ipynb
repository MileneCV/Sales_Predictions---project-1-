# %% [markdown]
# name: Milene Carmes Vallejo
#
# last updated: 1/23/2023

# %% [markdown]
# # Sales predictions

# %% [markdown]
# # Project Description

# %% [markdown]
# We are going to use a dataset from https://datahack.analyticsvidhya.com/contest/practice-problem-big-mart-sales-iii/. It is a sales prediction for food sold in various stores.
#
# The goal of this project is to help the retailer better understand which products and what factors influence increasing sales.

# %% [markdown]
# # Data Dictionary
#
# ![sales_predictions](Picture1.png)

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import missingno as msno

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.ticker import StrMethodFormatter
import statsmodels.api as sm
price_fmt = StrMethodFormatter("₹{x:,.0f}")
import warnings
import statsmodels.api as sm
warnings.filterwarnings('ignore')
from sklearn import metrics
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer 
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn import set_config
from scipy import stats
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import seaborn as sns
set_config(display='diagram')
import matplotlib.pyplot as plt
from matplotlib import legend
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import plot_tree

## saving variables for next lesson/notebook
import joblib

# %% [markdown]
# # Loading Data

# %%
filename = r"C:\Users\esnak\OneDrive\Desktop\coding_dojo\sales_predictions.csv"
df_sales = pd.read_csv(filename)

df_sales.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# # Prepare/clean the data

# %% [markdown]
# ## Display Rows and Column Count

# %%
df_sales.shape
print(f'There are {df_sales.shape[0]} rows, and {df_sales.shape[1]} columns.')
print(f'The rows represent {df_sales.shape[0]} observations, and the columns represent {df_sales.shape[1]-1} features and 1 target variable.')
# Out:
# There are 8523 rows, and 12 columns.
# The rows represent 8523 observations, and the columns represent 11 features and 1 target variable.

# %% [markdown]
# ## Display Column Names, Count of Non-Null Values, and Data Types

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# ## Duplicated Data

# %%
check_duplicate = df_sales.duplicated().sum()
if check_duplicate == 0:
  print('no duplicate were found to be dropped.')
else:
  print(f'(there are {check_duplicate} duplicates')
# Out:
# no duplicate were found to be dropped.

# %% [markdown]
# ## Missing Values

# %%
msno.matrix(df_sales, figsize=(16,3), labels=True, fontsize=12, sort="descending", color=	(.25,.4,.85));

# %%
df_sales.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Identifying % of missing data
df_sales.isna().sum()/len(df_sales)*100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %% [markdown]
# 17% of item_weight column is missing but we can some of them with item_identifier : all identical 'Item_Identifier' should have the same 'Item_Weight'

# %% [markdown]
# ### Item_Identifier column

# %%
# check 'Item_Identifier'
df_sales['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
# display nan in Item_weight column
nan_weight = df_sales[df_sales['Item_Weight'].isna()]
nan_weight
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# 18              Hard Drinks  113.2834            OUT027
# 21             Baking Goods  144.5444            OUT027
# 23             Baking Goods  107.6938            OUT019
# 29                   Canned   43.6454            OUT019
# ...                     ...       ...               ...
# 8485            Soft Drinks  189.0530            OUT027
# 8487            Soft Drinks  164.7526            OUT027
# 8488                 Others  184.6608            OUT027
# 8490  Fruits and Vegetables  162.3552            OUT019
# 8504              Household  111.7544            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7                          1985      Medium               Tier 3
# 18                         1985      Medium               Tier 3
# 21                         1985      Medium               Tier 3
# 23                         1985       Small               Tier 1
# 29                         1985       Small               Tier 1
# ...                         ...         ...                  ...
# 8485                       1985      Medium               Tier 3
# 8487                       1985      Medium               Tier 3
# 8488                       1985      Medium               Tier 3
# 8490                       1985       Small               Tier 1
# 8504                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 7     Supermarket Type3          4022.7636
# 18    Supermarket Type3          2303.6680
# 21    Supermarket Type3          4064.0432
# 23        Grocery Store           214.3876
# 29        Grocery Store           125.8362
# ...                 ...                ...
# 8485  Supermarket Type3          6261.8490
# 8487  Supermarket Type3          4111.3150
# 8488  Supermarket Type3          2756.4120
# 8490      Grocery Store           487.3656
# 8504  Supermarket Type3          4138.6128
#
# [1463 rows x 12 columns]

# %%
# create a new dataframe only with Item_Identifier and Item_Weight
df_ident_weight = df_sales[['Item_Identifier', 'Item_Weight']]
df_ident_weight
# Out:
#      Item_Identifier  Item_Weight
# 0              FDA15        9.300
# 1              DRC01        5.920
# 2              FDN15       17.500
# 3              FDX07       19.200
# 4              NCD19        8.930
# ...              ...          ...
# 8518           FDF22        6.865
# 8519           FDS36        8.380
# 8520           NCJ29       10.600
# 8521           FDN46        7.210
# 8522           DRG01       14.800
#
# [8523 rows x 2 columns]

# %%
# drop nan from filter
df_ident_weight = df_ident_weight.dropna()
df_ident_weight 
# now we know all weight for each item_identifier
# Out:
#      Item_Identifier  Item_Weight
# 0              FDA15        9.300
# 1              DRC01        5.920
# 2              FDN15       17.500
# 3              FDX07       19.200
# 4              NCD19        8.930
# ...              ...          ...
# 8518           FDF22        6.865
# 8519           FDS36        8.380
# 8520           NCJ29       10.600
# 8521           FDN46        7.210
# 8522           DRG01       14.800
#
# [7060 rows x 2 columns]

# %%
# Lets merge df_ident_weight and df_sales
result = pd.merge(df_sales, df_ident_weight, on= 'Item_Identifier', how='inner')
result
# Out:
#       Item_Identifier  Item_Weight_x Item_Fat_Content  Item_Visibility  \
# 0               FDA15           9.30          Low Fat         0.016047
# 1               FDA15           9.30          Low Fat         0.016047
# 2               FDA15           9.30          Low Fat         0.016047
# 3               FDA15           9.30          Low Fat         0.016047
# 4               FDA15           9.30          Low Fat         0.016047
# ...               ...            ...              ...              ...
# 41528           NCW30           5.21          Low Fat         0.011008
# 41529           NCW05          20.25          Low Fat         0.148303
# 41530           NCW05          20.25          Low Fat         0.148303
# 41531           NCW05          20.25          Low Fat         0.148373
# 41532           NCW05          20.25          Low Fat         0.148373
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0                   Dairy  249.8092            OUT049
# 1                   Dairy  249.8092            OUT049
# 2                   Dairy  249.8092            OUT049
# 3                   Dairy  249.8092            OUT049
# 4                   Dairy  249.8092            OUT049
# ...                   ...       ...               ...
# 41528           Household  259.5962            OUT035
# 41529  Health and Hygiene  108.3938            OUT049
# 41530  Health and Hygiene  108.3938            OUT049
# 41531  Health and Hygiene  108.8938            OUT045
# 41532  Health and Hygiene  108.8938            OUT045
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                           1999      Medium               Tier 1
# 1                           1999      Medium               Tier 1
# 2                           1999      Medium               Tier 1
# 3                           1999      Medium               Tier 1
# 4                           1999      Medium               Tier 1
# ...                          ...         ...                  ...
# 41528                       2004       Small               Tier 2
# 41529                       1999      Medium               Tier 1
# 41530                       1999      Medium               Tier 1
# 41531                       2002         NaN               Tier 2
# 41532                       2002         NaN               Tier 2
#
#              Outlet_Type  Item_Outlet_Sales  Item_Weight_y
# 0      Supermarket Type1          3735.1380           9.30
# 1      Supermarket Type1          3735.1380           9.30
# 2      Supermarket Type1          3735.1380           9.30
# 3      Supermarket Type1          3735.1380           9.30
# 4      Supermarket Type1          3735.1380           9.30
# ...                  ...                ...            ...
# 41528  Supermarket Type1          2848.9582           5.21
# 41529  Supermarket Type1          2787.0388          20.25
# 41530  Supermarket Type1          2787.0388          20.25
# 41531  Supermarket Type1          3644.5892          20.25
# 41532  Supermarket Type1          3644.5892          20.25
#
# [41533 rows x 13 columns]

# %%
# check missing values
result.isna().sum()
# Out:
# Item_Identifier                  0
# Item_Weight_x                 6597
# Item_Fat_Content                 0
# Item_Visibility                  0
# Item_Type                        0
# Item_MRP                         0
# Outlet_Identifier                0
# Outlet_Establishment_Year        0
# Outlet_Size                  12035
# Outlet_Location_Type             0
# Outlet_Type                      0
# Item_Outlet_Sales                0
# Item_Weight_y                    0
# dtype: int64

# %%
# drop column Item_Weight_x with missing values and keep Item_Weight_y  
df_sales1 = result.drop(columns='Item_Weight_x')
df_sales1.isna().sum()
# Out:
# Item_Identifier                  0
# Item_Fat_Content                 0
# Item_Visibility                  0
# Item_Type                        0
# Item_MRP                         0
# Outlet_Identifier                0
# Outlet_Establishment_Year        0
# Outlet_Size                  12035
# Outlet_Location_Type             0
# Outlet_Type                      0
# Item_Outlet_Sales                0
# Item_Weight_y                    0
# dtype: int64

# %%
# set item_identifier as index
df_sales1.set_index('Item_Identifier')
# Out:
#                 Item_Fat_Content  Item_Visibility           Item_Type  \
# Item_Identifier
# FDA15                    Low Fat         0.016047               Dairy
# FDA15                    Low Fat         0.016047               Dairy
# FDA15                    Low Fat         0.016047               Dairy
# FDA15                    Low Fat         0.016047               Dairy
# FDA15                    Low Fat         0.016047               Dairy
# ...                          ...              ...                 ...
# NCW30                    Low Fat         0.011008           Household
# NCW05                    Low Fat         0.148303  Health and Hygiene
# NCW05                    Low Fat         0.148303  Health and Hygiene
# NCW05                    Low Fat         0.148373  Health and Hygiene
# NCW05                    Low Fat         0.148373  Health and Hygiene
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# FDA15            249.8092            OUT049                       1999
# FDA15            249.8092            OUT049                       1999
# FDA15            249.8092            OUT049                       1999
# FDA15            249.8092            OUT049                       1999
# FDA15            249.8092            OUT049                       1999
# ...                   ...               ...                        ...
# NCW30            259.5962            OUT035                       2004
# NCW05            108.3938            OUT049                       1999
# NCW05            108.3938            OUT049                       1999
# NCW05            108.8938            OUT045                       2002
# NCW05            108.8938            OUT045                       2002
#
#                 Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Identifier
# FDA15                Medium               Tier 1  Supermarket Type1
# FDA15                Medium               Tier 1  Supermarket Type1
# FDA15                Medium               Tier 1  Supermarket Type1
# FDA15                Medium               Tier 1  Supermarket Type1
# FDA15                Medium               Tier 1  Supermarket Type1
# ...                     ...                  ...                ...
# NCW30                 Small               Tier 2  Supermarket Type1
# NCW05                Medium               Tier 1  Supermarket Type1
# NCW05                Medium               Tier 1  Supermarket Type1
# NCW05                   NaN               Tier 2  Supermarket Type1
# NCW05                   NaN               Tier 2  Supermarket Type1
#
#                  Item_Outlet_Sales  Item_Weight_y
# Item_Identifier
# FDA15                    3735.1380           9.30
# FDA15                    3735.1380           9.30
# FDA15                    3735.1380           9.30
# FDA15                    3735.1380           9.30
# FDA15                    3735.1380           9.30
# ...                            ...            ...
# NCW30                    2848.9582           5.21
# NCW05                    2787.0388          20.25
# NCW05                    2787.0388          20.25
# NCW05                    3644.5892          20.25
# NCW05                    3644.5892          20.25
#
# [41533 rows x 11 columns]

# %%
# drop duplicates
df_sales = df_sales1.drop_duplicates()
# check duplicates
df_sales.duplicated().sum()
# Out:
# 0

# %%
df_sales.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# Item_Weight_y                   0
# dtype: int64

# %% [markdown]
# ### Outlet_Size column

# %%
# Let's try to find some clues  to fill missing values
df_sales.groupby(['Outlet_Type','Outlet_Location_Type'])['Outlet_Size'].unique()
# Out:
# Outlet_Type        Outlet_Location_Type
# Grocery Store      Tier 1                          [Small]
#                    Tier 3                            [nan]
# Supermarket Type1  Tier 1                  [Medium, Small]
#                    Tier 2                     [nan, Small]
#                    Tier 3                           [High]
# Supermarket Type2  Tier 3                         [Medium]
# Supermarket Type3  Tier 3                         [Medium]
# Name: Outlet_Size, dtype: object

# %% [markdown]
# There are missing values in Outlet_Location_Type tier 3 but we are unable to find some clues. Let's replace Nan with 'Unknown'

# %%
df_sales['Outlet_Size'].fillna('Unknown',inplace=True)

# %%
# Confirm that there are no missing values after addressing them.
df_sales.isna().sum()
# Out:
# Item_Identifier              0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Item_Weight_y                0
# dtype: int64

# %% [markdown]
# ## Find and fix any inconsistent categories of data
# Check for common syntax errors, typos or inconsistencies in strings that need to be fixed.

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8519 entries, 0 to 41531
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8519 non-null   object
#  1   Item_Fat_Content           8519 non-null   object
#  2   Item_Visibility            8519 non-null   float64
#  3   Item_Type                  8519 non-null   object
#  4   Item_MRP                   8519 non-null   float64
#  5   Outlet_Identifier          8519 non-null   object
#  6   Outlet_Establishment_Year  8519 non-null   int64
#  7   Outlet_Size                8519 non-null   object
#  8   Outlet_Location_Type       8519 non-null   object
#  9   Outlet_Type                8519 non-null   object
#  10  Item_Outlet_Sales          8519 non-null   float64
#  11  Item_Weight_y              8519 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 865.2+ KB

# %% [markdown]
# ### Object columns

# %%
# this code will fiter out the object type columns and creates a list of each of column names as an index
df_sales_types = df_sales.dtypes
str_cols = df_sales_types[df_sales_types=='object'].index
str_cols
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
# This for loop prints out each column name and then lists each category
# in the column along with the counts of each category
for col in str_cols:
  print(f'- {col}:')
  print(df_sales[col].value_counts(dropna=False))
  print('\n')
# Out:
# - Item_Identifier:
# FDG33    10
# FDW13    10
# FDV60     9
# FDU12     9
# FDX20     9
#          ..
# DRF48     1
# FDY43     1
# FDC23     1
# FDO33     1
# FDT35     1
# Name: Item_Identifier, Length: 1555, dtype: int64
#
#
# - Item_Fat_Content:
# Low Fat    5088
# Regular    2886
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64
#
#
# - Item_Type:
# Fruits and Vegetables    1232
# Snack Foods              1199
# Household                 910
# Frozen Foods              855
# Dairy                     681
# Canned                    649
# Baking Goods              647
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
#
# - Outlet_Identifier:
# OUT013    932
# OUT027    932
# OUT049    930
# OUT035    930
# OUT046    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    527
# Name: Outlet_Identifier, dtype: int64
#
#
# - Outlet_Size:
# Medium     2790
# Unknown    2410
# Small      2387
# High        932
# Name: Outlet_Size, dtype: int64
#
#
# - Outlet_Location_Type:
# Tier 3    3347
# Tier 2    2785
# Tier 1    2387
# Name: Outlet_Location_Type, dtype: int64
#
#
# - Outlet_Type:
# Supermarket Type1    5577
# Grocery Store        1082
# Supermarket Type3     932
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
# something is wrong with "Item_fat_content"
# replace to be 2 type : Low Fat and Regular
# Define a dictionary with key/value pairs and use it to replace values
dict = {"low fat": 'Low Fat', "reg": 'Regular', "LF": 'Low Fat'}
df_sales.replace({'Item_Fat_Content': dict}, inplace = True)

# %%
# check 'Item_Fat_Content'
df_sales['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %% [markdown]
# ### Numeric columns

# %%
# Obtain the summary statistics of each (min, max, mean).
df_sales.describe()
# Out:
#        Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count      8519.000000  8519.000000                8519.000000
# mean          0.066112   141.010019                1997.837892
# std           0.051586    62.283594                   8.369105
# min           0.000000    31.290000                1985.000000
# 25%           0.026983    93.844900                1987.000000
# 50%           0.053925   143.047000                1999.000000
# 75%           0.094558   185.676600                2004.000000
# max           0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales  Item_Weight_y
# count        8519.000000    8519.000000
# mean         2181.188779      12.875420
# std          1706.511093       4.646098
# min            33.290000       4.555000
# 25%           834.247400       8.785000
# 50%          1794.331000      12.650000
# 75%          3100.630600      16.850000
# max         13086.964800      21.350000

# %% [markdown]
# No unusual statistics were noted.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### object columns

# %%
# select categorical columns
df_sales_types = df_sales.dtypes
str_cols = df_sales_types[df_sales_types=='object'].index
str_cols
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
# Create a function to plot all string columns
def plot_bar_all_features(df1,x):
  fig, ax = plt.subplots(figsize=(8,5))
  counts_x = df1[x].value_counts()
  print(f'Value_counts {x}')
  print(counts_x)
  print('\n', '\n')
  counts_x.plot(kind='barh')
  ax.set_facecolor("lightgray")
 
  ax.set_title(f'Frequencies of {x}', fontsize = 20, fontweight = 'bold');
  ax.set_ylabel(f'Categories for {x}', fontsize = 15, fontweight = 'bold')
  ax.set_xlabel('Counts', fontsize = 15, fontweight = 'bold')

# %%
plot_bar_all_features(df_sales, 'Item_Fat_Content')
# Out:
# Value_counts Item_Fat_Content
# Low Fat    5516
# Regular    3003
# Name: Item_Fat_Content, dtype: int64

# %%
plot_bar_all_features(df_sales, 'Item_Type')
# Out:
# Value_counts Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1199
# Household                 910
# Frozen Foods              855
# Dairy                     681
# Canned                    649
# Baking Goods              647
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %% [markdown]
# In this dataset there are more fruit/vegetables and snack foods(about 1200) and less sea food and breakfast (about 100).

# %%
plot_bar_all_features(df_sales, 'Outlet_Establishment_Year')
# Out:
# Value_counts Outlet_Establishment_Year
# 1985    1459
# 1987     932
# 1999     930
# 2004     930
# 1997     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
plot_bar_all_features(df_sales, 'Outlet_Size')
# Out:
# Value_counts Outlet_Size
# Medium     2790
# Unknown    2410
# Small      2387
# High        932
# Name: Outlet_Size, dtype: int64

# %%
plot_bar_all_features(df_sales, 'Outlet_Location_Type')
# Out:
# Value_counts Outlet_Location_Type
# Tier 3    3347
# Tier 2    2785
# Tier 1    2387
# Name: Outlet_Location_Type, dtype: int64

# %%
plot_bar_all_features(df_sales, 'Outlet_Type')
# Out:
# Value_counts Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1082
# Supermarket Type3     932
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# ### numeric columns

# %%
df_sales.describe()
# Out:
#        Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count      8519.000000  8519.000000                8519.000000
# mean          0.066112   141.010019                1997.837892
# std           0.051586    62.283594                   8.369105
# min           0.000000    31.290000                1985.000000
# 25%           0.026983    93.844900                1987.000000
# 50%           0.053925   143.047000                1999.000000
# 75%           0.094558   185.676600                2004.000000
# max           0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales  Item_Weight_y
# count        8519.000000    8519.000000
# mean         2181.188779      12.875420
# std          1706.511093       4.646098
# min            33.290000       4.555000
# 25%           834.247400       8.785000
# 50%          1794.331000      12.650000
# 75%          3100.630600      16.850000
# max         13086.964800      21.350000

# %%
def plot_numeric(df,col):
  """EDA function to plot a histogram and boxplot for the selected column"""
  ## make the figure and axes sharing the same x-axis
  fig, axes = plt.subplots(nrows=2, figsize=(10,5), sharex=True)

  ## Use seaborn plots with ax=axes[i]
  sns.histplot(data=df,x = col,ax = axes[0], bins = 100)
  mean_value = df[col].mean()
  axes[0].axvline(mean_value,color='red', ls='--', 
           label=f"Mean Value = ${mean_value:,.2f}",);
  axes[0].legend()
  axes[0].set_facecolor("lightgray")

  sns.boxplot(data=df, x = col, ax = axes[1])
  axes[1].set_facecolor("lightgray")
  ## Updating title of top graph 
  axes[0].set_title(f'Distribution of {col}', fontsize = 20, fontweight = 'bold')

  ## Fixing any overlapping labels and showing
  plt.tight_layout()
  plt.show()

# %%
plot_numeric(df_sales,'Item_Visibility')

# %%
plot_numeric(df_sales,'Item_Weight_y')

# %%
plot_numeric(df_sales,'Item_MRP')

# %% [markdown]
# Most of the products have a price between ₹30 and ₹190. The mean price is ₹141.01 and the maximun valor is about ₹260

# %%
plot_numeric(df_sales,'Item_Outlet_Sales')

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize = (8, 8))
# Calculating the mask to hide the upper-right of the triangle
corr = df_sales.corr()
mask = np.triu(np.ones_like(corr))
sns.heatmap(corr, cmap='viridis', annot=True, mask=mask);

plt.title('Correlation Heatmap', fontsize = 16, weight='bold')
plt.xticks(fontsize = 10, weight='bold', rotation=90)
plt.yticks(fontsize = 10, weight='bold');

plt.tight_layout()
plt.show;

# %% [markdown]
# #### Observation:
#
# Item MRP has the highest correlation to Item Outlet Sales. Any features that have a correlation value of less than -0.8 or greater than +0.8, so we don't have Multicollinearity a important assumption for Linear Regression model.

# %% [markdown]
# ## Explanatory Data Analysis

# %% [markdown]
# ### Correlation between price and sales

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=df_sales, x='Item_MRP', y='Item_Outlet_Sales', hue='Outlet_Type')
plt.title('Correlation between price and sales', fontsize=20, weight = 'bold')
plt.ylabel('Sales(₹)', fontsize=15, weight = 'bold')
plt.xlabel('Price(₹)', fontsize=15, weight = 'bold')

plt.legend(bbox_to_anchor=(1,0.4), title = 'Outlet Type')

plt.show()

# %% [markdown]
# In supermarket type 1, 2 and 3 there is a positive correlation between price and sales number. In grocery store is hard to see this correlation.

# %% [markdown]
# ### Which Items generate the greatest amount of sales?

# %%
top_selling_item_types = df_sales.groupby('Item_Type')['Item_Outlet_Sales'].sum()
df_top = pd.DataFrame(top_selling_item_types).sort_values('Item_Outlet_Sales', ascending = False)
df_top
# Out:
#                        Item_Outlet_Sales
# Item_Type
# Fruits and Vegetables       2.820060e+06
# Snack Foods                 2.728352e+06
# Household                   2.055494e+06
# Frozen Foods                1.824165e+06
# Dairy                       1.519141e+06
# Canned                      1.444151e+06
# Baking Goods                1.265405e+06
# Health and Hygiene          1.045200e+06
# Meat                        9.175656e+05
# Soft Drinks                 8.928977e+05
# Breads                      5.532372e+05
# Hard Drinks                 4.577934e+05
# Starchy Foods               3.514013e+05
# Others                      3.255176e+05
# Breakfast                   2.322990e+05
# Seafood                     1.488682e+05

# %%
sns.blend_palette(['blue', 'red'])
# Out:
# [(0.0, 0.0, 1.0),
#  (0.2, 0.0, 0.8),
#  (0.4, 0.0, 0.6),
#  (0.6, 0.0, 0.4),
#  (0.8, 0.0, 0.19999999999999996),
#  (1.0, 0.0, 0.0)]

# %%
palette = sns.blend_palette(['blue', 'red'])
fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(data=df_top, x='Item_Outlet_Sales', y=df_top.index, orient='h', palette=palette); 

plt.title('Top Selling Item Types', fontsize = 18, weight='bold')
plt.xlabel('Total Sales', fontsize = 14, weight='bold')
plt.ylabel('Item Type', fontsize = 14, weight='bold');
plt.xticks(fontsize = 10, weight='bold')
plt.yticks(fontsize = 10, weight='bold');
ax.xaxis.set_major_formatter(price_fmt)
plt.tight_layout()
plt.show;

# %% [markdown]
# Fruits and Vegetables and snack foods are the top selling item with more than ₹2,500,00 in sales.

# %% [markdown]
# ### Which outlet has better sales?

# %%
# check outlet with better sales 
df_group_type_outlet = df_sales.groupby(['Outlet_Type', 'Outlet_Identifier'])['Item_Outlet_Sales'].sum().reset_index().sort_values('Item_Outlet_Sales')
df_group_type_outlet
# Out:
#          Outlet_Type Outlet_Identifier  Item_Outlet_Sales
# 1      Grocery Store            OUT019       1.795736e+05
# 0      Grocery Store            OUT010       1.883402e+05
# 8  Supermarket Type2            OUT018       1.851823e+06
# 5  Supermarket Type1            OUT045       2.036725e+06
# 6  Supermarket Type1            OUT046       2.118395e+06
# 2  Supermarket Type1            OUT013       2.142664e+06
# 3  Supermarket Type1            OUT017       2.167465e+06
# 7  Supermarket Type1            OUT049       2.183970e+06
# 4  Supermarket Type1            OUT035       2.268123e+06
# 9  Supermarket Type3            OUT027       3.444468e+06

# %%
fig, ax = plt.subplots(figsize=(12,4))
sns.barplot(data=df_group_type_outlet, x='Item_Outlet_Sales', y='Outlet_Identifier', hue='Outlet_Type', order=df_group_type_outlet['Outlet_Identifier'])
plt.legend(bbox_to_anchor=(1,0.3), title= 'Outlet Type' )
plt.title('Distribution of sales by outlet', fontsize=20)
plt.xlabel('Sales(₹)', fontsize=15)
plt.ylabel('Outlet Identifier', fontsize=15)
ax.xaxis.set_major_formatter(price_fmt)
plt.show()

# %% [markdown]
# The outlet OUT027, wich is a supermarket type 3, has better sales than other outlets. Grocery stores OUT010, OUT019 have lower sales. Supermarket Type1 contributed significantly of total sales

# %% [markdown]
# ### Which outlet type has better sales?

# %%
# check outlet type with better sales 
df_group_type = df_sales.groupby(['Outlet_Type'])['Item_Outlet_Sales'].sum().reset_index().sort_values('Item_Outlet_Sales')
df_group_type
# Out:
#          Outlet_Type  Item_Outlet_Sales
# 0      Grocery Store       3.679138e+05
# 2  Supermarket Type2       1.851823e+06
# 3  Supermarket Type3       3.444468e+06
# 1  Supermarket Type1       1.291734e+07

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.barplot(data=df_group_type, x='Item_Outlet_Sales', y='Outlet_Type', palette= palette)

plt.title('Distribution of sales by outlet type', fontsize=20)
plt.xlabel('Sales(₹)', fontsize=15)
plt.ylabel('Outlet type', fontsize=15)
ax.xaxis.set_major_formatter(price_fmt)

# %% [markdown]
# Supermarket Type1 has higher total sales.

# %% [markdown]
# ### Does Location affect Sales?

# %%
location_sales_sorted = df_sales.groupby(['Outlet_Location_Type'])['Item_Outlet_Sales'].sum().reset_index().sort_values('Item_Outlet_Sales')
location_sales_sorted
# Out:
#   Outlet_Location_Type  Item_Outlet_Sales
# 0               Tier 1       4.481939e+06
# 1               Tier 2       6.472314e+06
# 2               Tier 3       7.627295e+06

# %%
fig, ax = plt.subplots(figsize=(12,6))
sns.barplot(data=location_sales_sorted, x='Item_Outlet_Sales', y='Outlet_Location_Type', palette=palette)
plt.title('Distribution of sales by location', fontsize=20)
plt.xlabel('Sales(₹)', fontsize=15)
plt.ylabel('Location', fontsize=15)
ax.xaxis.set_major_formatter(price_fmt)

# %% [markdown]
# Tier 3 Outlet Location has higher sales.

# %%
# check what type of outlet are in tier 3 
location_sales_sorted = df_sales.groupby(['Outlet_Location_Type', 'Outlet_Type'])['Item_Outlet_Sales'].sum().reset_index().sort_values('Item_Outlet_Sales')
fig, ax = plt.subplots(figsize=(12,6))
sns.barplot(data=location_sales_sorted, x='Item_Outlet_Sales', y='Outlet_Type', hue= 'Outlet_Location_Type', palette=palette)
plt.title('Distribution of sales by location and type outlet', fontsize=20)
plt.xlabel('Sales(₹)', fontsize=15)
plt.ylabel('Outlet Type', fontsize=15)
plt.legend(bbox_to_anchor=(1,0.7), title= 'Location')
ax.xaxis.set_major_formatter(price_fmt)

plt.show()

# %% [markdown]
# The type of the area in which the store is located is related to better sales. Because the Supermarket type 1 which has  better sales is located in all tier and at Tier 2 it has higher sales than Tier 1 and Tier 2.

# %% [markdown]
# ### Does the year in which store was established is related with better sales?

# %%
# check if The year in which store was established is related with better sales. 
year_sales = df_sales.groupby(['Outlet_Establishment_Year', 'Outlet_Type'])['Item_Outlet_Sales'].sum().reset_index().sort_values('Outlet_Establishment_Year')
fig, ax = plt.subplots(figsize=(12,6))
sns.barplot(data=year_sales, y='Item_Outlet_Sales', hue= 'Outlet_Type',  x = 'Outlet_Establishment_Year', palette=palette)
plt.title('Distribution of sales by Outlet Establishment Year', fontsize=15)
plt.ylabel('Sales(₹)', fontsize=15)
plt.xlabel('Establishment Year', fontsize=15)
plt.legend(bbox_to_anchor=(1,0.3), title= 'Outlet Type')
plt.xticks(rotation = 90)
plt.xticks(rotation = 25)
ax.yaxis.set_major_formatter(price_fmt)
plt.show()

# %% [markdown]
# The year in which stores were established is not related to better sales. During the years 1987 until 2007 were established different Supermarket Type 1 and there is no big difference between them.

# %% [markdown]
# # Preprocessing for Machine Learning

# %%
# load df again for machine learning 
df_ml = pd.read_csv(filename)
df_ml
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# 1               Soft Drinks   48.2692            OUT018
# 2                      Meat  141.6180            OUT049
# 3     Fruits and Vegetables  182.0950            OUT010
# 4                 Household   53.8614            OUT013
# ...                     ...       ...               ...
# 8518            Snack Foods  214.5218            OUT013
# 8519           Baking Goods  108.1570            OUT045
# 8520     Health and Hygiene   85.1224            OUT035
# 8521            Snack Foods  103.1332            OUT018
# 8522            Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                          1999      Medium               Tier 1
# 1                          2009      Medium               Tier 3
# 2                          1999      Medium               Tier 1
# 3                          1998         NaN               Tier 3
# 4                          1987        High               Tier 3
# ...                         ...         ...                  ...
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# 8520                       2004       Small               Tier 2
# 8521                       2009      Medium               Tier 3
# 8522                       1997       Small               Tier 1
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 1     Supermarket Type2           443.4228
# 2     Supermarket Type1          2097.2700
# 3         Grocery Store           732.3800
# 4     Supermarket Type1           994.7052
# ...                 ...                ...
# 8518  Supermarket Type1          2778.3834
# 8519  Supermarket Type1           549.2850
# 8520  Supermarket Type1          1193.1136
# 8521  Supermarket Type2          1845.5976
# 8522  Supermarket Type1           765.6700
#
# [8523 rows x 12 columns]

# %%
# fix inconsistencies in 'Item_Fat_Content' column
dict_names = {'LF':'Low Fat', 'low fat': 'Low Fat', 'reg':'Regular'}
df_ml['Item_Fat_Content']. replace(dict_names, inplace = True)
df_ml['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
# 'Outlet_Establishment_Year' is a date/time and will be included with categorical features
df_ml['Outlet_Establishment_Year'] = df_ml['Outlet_Establishment_Year'].astype("object")

# %%
# check unique values 
df_ml.select_dtypes('object').nunique()
# Out:
# Item_Identifier              1559
# Item_Fat_Content                2
# Item_Type                      16
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# dtype: int64

# %% [markdown]
# ## Train/Test split
# "Item_Outlet_Sales" column as target

# %%
# matrix  - drop columns 'Item_Identifier' (this feature will not make any contribution in model building. There are too many unique values 
X = df_ml.drop(columns=['Item_Outlet_Sales', 'Item_Identifier'])

# target
y = df_ml['Item_Outlet_Sales']

# Perform a train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

print('size of X_train(75% of df_sales)')
print(len(X_train))

X_train.head()
# Out:
# size of X_train(75% of df_sales)
# 6392
#       Item_Weight Item_Fat_Content  Item_Visibility     Item_Type  Item_MRP  \
# 4776       16.350          Low Fat         0.029565     Household  256.4646
# 7510       15.250          Regular         0.000000   Snack Foods  179.7660
# 5828       12.350          Regular         0.158716          Meat  157.2946
# 5327        7.975          Low Fat         0.014628  Baking Goods   82.3250
# 4810       19.350          Low Fat         0.016645  Frozen Foods  120.9098
#
#      Outlet_Identifier Outlet_Establishment_Year Outlet_Size  \
# 4776            OUT018                      2009      Medium
# 7510            OUT018                      2009      Medium
# 5828            OUT049                      1999      Medium
# 5327            OUT035                      2004       Small
# 4810            OUT045                      2002         NaN
#
#      Outlet_Location_Type        Outlet_Type
# 4776               Tier 3  Supermarket Type2
# 7510               Tier 3  Supermarket Type2
# 5828               Tier 1  Supermarket Type1
# 5327               Tier 2  Supermarket Type1
# 4810               Tier 2  Supermarket Type1

# %% [markdown]
# ## Selector columns

# %%
# make column selector :
# numerical columns
num_sel = make_column_selector(dtype_include = 'number')

# categorical columns
cat_sel = make_column_selector(dtype_include = 'object')

# %%
cat_sel(X_train)
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Establishment_Year',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type']

# %%
num_sel(X_train)
# Out:
# ['Item_Weight', 'Item_Visibility', 'Item_MRP']

# %% [markdown]
# ## Impute any missing values.

# %%
# check missing values 
df_ml.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# There are missing values in numeric column Item_Weight that is float and categorical column Outlet_Size

# %% [markdown]
# ## Instantiate Transformers : One HotEncoder

# %%
ohe = OneHotEncoder(handle_unknown = 'ignore', sparse = False)

# %% [markdown]
# ## Instantiate Pipelines

# %%
## make pipelines for categorical vs numeric data
cat_pipe = make_pipeline(SimpleImputer(strategy='constant', fill_value='MISSING'),
                         OneHotEncoder(handle_unknown='ignore', sparse=False))
num_pipe = make_pipeline(SimpleImputer(strategy='mean'))

# %% [markdown]
# ## Instantiate ColumnTransformer

# %%
## make the preprocessing column transformer
preprocessor = make_column_transformer((num_pipe, num_sel),
                                       (cat_pipe,cat_sel),                                      
                                       verbose_feature_names_out=False)
preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000024F9D1D8670>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000024F9DEA7B50>)],
#                   verbose_feature_names_out=False)

# %% [markdown]
# ## Fit in X_train

# %%
# Fit on Train
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000024F9D1D8670>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000024F9DEA7B50>)],
#                   verbose_feature_names_out=False)

# %% [markdown]
# ## Get feature names out

# %%
feature_names = preprocessor.get_feature_names_out()
feature_names
# Out:
# array(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Item_Fat_Content_Low Fat', 'Item_Fat_Content_Regular',
#        'Item_Type_Baking Goods', 'Item_Type_Breads',
#        'Item_Type_Breakfast', 'Item_Type_Canned', 'Item_Type_Dairy',
#        'Item_Type_Frozen Foods', 'Item_Type_Fruits and Vegetables',
#        'Item_Type_Hard Drinks', 'Item_Type_Health and Hygiene',
#        'Item_Type_Household', 'Item_Type_Meat', 'Item_Type_Others',
#        'Item_Type_Seafood', 'Item_Type_Snack Foods',
#        'Item_Type_Soft Drinks', 'Item_Type_Starchy Foods',
#        'Outlet_Identifier_OUT010', 'Outlet_Identifier_OUT013',
#        'Outlet_Identifier_OUT017', 'Outlet_Identifier_OUT018',
#        'Outlet_Identifier_OUT019', 'Outlet_Identifier_OUT027',
#        'Outlet_Identifier_OUT035', 'Outlet_Identifier_OUT045',
#        'Outlet_Identifier_OUT046', 'Outlet_Identifier_OUT049',
#        'Outlet_Establishment_Year_1985', 'Outlet_Establishment_Year_1987',
#        'Outlet_Establishment_Year_1997', 'Outlet_Establishment_Year_1998',
#        'Outlet_Establishment_Year_1999', 'Outlet_Establishment_Year_2002',
#        'Outlet_Establishment_Year_2004', 'Outlet_Establishment_Year_2007',
#        'Outlet_Establishment_Year_2009', 'Outlet_Size_High',
#        'Outlet_Size_MISSING', 'Outlet_Size_Medium', 'Outlet_Size_Small',
#        'Outlet_Location_Type_Tier 1', 'Outlet_Location_Type_Tier 2',
#        'Outlet_Location_Type_Tier 3', 'Outlet_Type_Grocery Store',
#        'Outlet_Type_Supermarket Type1', 'Outlet_Type_Supermarket Type2',
#        'Outlet_Type_Supermarket Type3'], dtype=object)

# %% [markdown]
# ## Remaking Our X_train and X_test as DataFrames with the New Feature Names

# %%
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                           columns = feature_names, index = X_train.index)
X_train_df.head(3)
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Fat_Content_Low Fat  \
# 4776        16.35         0.029565  256.4646                       1.0
# 7510        15.25         0.000000  179.7660                       0.0
# 5828        12.35         0.158716  157.2946                       0.0
#
#       Item_Fat_Content_Regular  Item_Type_Baking Goods  Item_Type_Breads  \
# 4776                       0.0                     0.0               0.0
# 7510                       1.0                     0.0               0.0
# 5828                       1.0                     0.0               0.0
#
#       Item_Type_Breakfast  Item_Type_Canned  Item_Type_Dairy  ...  \
# 4776                  0.0               0.0              0.0  ...
# 7510                  0.0               0.0              0.0  ...
# 5828                  0.0               0.0              0.0  ...
#
#       Outlet_Size_MISSING  Outlet_Size_Medium  Outlet_Size_Small  \
# 4776                  0.0                 1.0                0.0
# 7510                  0.0                 1.0                0.0
# 5828                  0.0                 1.0                0.0
#
#       Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# 4776                          0.0                          0.0
# 7510                          0.0                          0.0
# 5828                          1.0                          0.0
#
#       Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# 4776                          1.0                        0.0
# 7510                          1.0                        0.0
# 5828                          0.0                        0.0
#
#       Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 4776                            0.0                            1.0
# 7510                            0.0                            1.0
# 5828                            1.0                            0.0
#
#       Outlet_Type_Supermarket Type3
# 4776                            0.0
# 7510                            0.0
# 5828                            0.0
#
# [3 rows x 51 columns]

# %%
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                           columns = feature_names, index = X_test.index)
X_test_df.head(3)
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Fat_Content_Low Fat  \
# 7503        14.30         0.026300   79.4302                       1.0
# 2957         7.93         0.071136   42.7086                       1.0
# 7031        14.50         0.041313   42.0454                       0.0
#
#       Item_Fat_Content_Regular  Item_Type_Baking Goods  Item_Type_Breads  \
# 7503                       0.0                     0.0               0.0
# 2957                       0.0                     0.0               0.0
# 7031                       1.0                     0.0               0.0
#
#       Item_Type_Breakfast  Item_Type_Canned  Item_Type_Dairy  ...  \
# 7503                  0.0               0.0              0.0  ...
# 2957                  0.0               0.0              0.0  ...
# 7031                  0.0               1.0              0.0  ...
#
#       Outlet_Size_MISSING  Outlet_Size_Medium  Outlet_Size_Small  \
# 7503                  0.0                 0.0                0.0
# 2957                  0.0                 0.0                1.0
# 7031                  0.0                 1.0                0.0
#
#       Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# 7503                          0.0                          0.0
# 2957                          1.0                          0.0
# 7031                          1.0                          0.0
#
#       Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# 7503                          1.0                        0.0
# 2957                          0.0                        0.0
# 7031                          0.0                        0.0
#
#       Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 7503                            1.0                            0.0
# 2957                            1.0                            0.0
# 7031                            1.0                            0.0
#
#       Outlet_Type_Supermarket Type3
# 7503                            0.0
# 2957                            0.0
# 7031                            0.0
#
# [3 rows x 51 columns]

# %%
## confirm the first 3 rows index in y_test matches X_test_df
y_test.head(3)
# Out:
# 7503    1743.0644
# 2957     356.8688
# 7031     377.5086
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# ## Inspect the Result

# %%
# Check for missing values and that data is scaled and one-hot encoded
print(np.isnan(X_train_df).sum().sum(), 'missing values in training data')
print(np.isnan(X_test_df).sum().sum(), 'missing values in testing data')
print('\n')
print('shape of data is', X_train_df.shape)
print('\n')
X_train_df
# Out:
# 0 missing values in training data
# 0 missing values in testing data
#
#
# shape of data is (6392, 51)
#       Item_Weight  Item_Visibility  Item_MRP  Item_Fat_Content_Low Fat  \
# 4776       16.350         0.029565  256.4646                       1.0
# 7510       15.250         0.000000  179.7660                       0.0
# 5828       12.350         0.158716  157.2946                       0.0
# 5327        7.975         0.014628   82.3250                       1.0
# 4810       19.350         0.016645  120.9098                       1.0
# ...           ...              ...       ...                       ...
# 5734        9.395         0.286345  139.1838                       0.0
# 5191       15.600         0.117575   75.6670                       1.0
# 5390       17.600         0.018944  237.3590                       1.0
# 860        20.350         0.054363  117.9466                       1.0
# 7270       16.350         0.016993   95.7410                       1.0
#
#       Item_Fat_Content_Regular  Item_Type_Baking Goods  Item_Type_Breads  \
# 4776                       0.0                     0.0               0.0
# 7510                       1.0                     0.0               0.0
# 5828                       1.0                     0.0               0.0
# 5327                       0.0                     1.0               0.0
# 4810                       0.0                     0.0               0.0
# ...                        ...                     ...               ...
# 5734                       1.0                     0.0               0.0
# 5191                       0.0                     0.0               0.0
# 5390                       0.0                     0.0               0.0
# 860                        0.0                     0.0               0.0
# 7270                       0.0                     0.0               0.0
#
#       Item_Type_Breakfast  Item_Type_Canned  Item_Type_Dairy  ...  \
# 4776                  0.0               0.0              0.0  ...
# 7510                  0.0               0.0              0.0  ...
# 5828                  0.0               0.0              0.0  ...
# 5327                  0.0               0.0              0.0  ...
# 4810                  0.0               0.0              0.0  ...
# ...                   ...               ...              ...  ...
# 5734                  0.0               0.0              0.0  ...
# 5191                  0.0               0.0              0.0  ...
# 5390                  0.0               0.0              0.0  ...
# 860                   0.0               0.0              0.0  ...
# 7270                  0.0               0.0              0.0  ...
#
#       Outlet_Size_MISSING  Outlet_Size_Medium  Outlet_Size_Small  \
# 4776                  0.0                 1.0                0.0
# 7510                  0.0                 1.0                0.0
# 5828                  0.0                 1.0                0.0
# 5327                  0.0                 0.0                1.0
# 4810                  1.0                 0.0                0.0
# ...                   ...                 ...                ...
# 5734                  1.0                 0.0                0.0
# 5191                  1.0                 0.0                0.0
# 5390                  1.0                 0.0                0.0
# 860                   1.0                 0.0                0.0
# 7270                  0.0                 0.0                1.0
#
#       Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# 4776                          0.0                          0.0
# 7510                          0.0                          0.0
# 5828                          1.0                          0.0
# 5327                          0.0                          1.0
# 4810                          0.0                          1.0
# ...                           ...                          ...
# 5734                          0.0                          0.0
# 5191                          0.0                          1.0
# 5390                          0.0                          1.0
# 860                           0.0                          1.0
# 7270                          1.0                          0.0
#
#       Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# 4776                          1.0                        0.0
# 7510                          1.0                        0.0
# 5828                          0.0                        0.0
# 5327                          0.0                        0.0
# 4810                          0.0                        0.0
# ...                           ...                        ...
# 5734                          1.0                        1.0
# 5191                          0.0                        0.0
# 5390                          0.0                        0.0
# 860                           0.0                        0.0
# 7270                          0.0                        0.0
#
#       Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 4776                            0.0                            1.0
# 7510                            0.0                            1.0
# 5828                            1.0                            0.0
# 5327                            1.0                            0.0
# 4810                            1.0                            0.0
# ...                             ...                            ...
# 5734                            0.0                            0.0
# 5191                            1.0                            0.0
# 5390                            1.0                            0.0
# 860                             1.0                            0.0
# 7270                            1.0                            0.0
#
#       Outlet_Type_Supermarket Type3
# 4776                            0.0
# 7510                            0.0
# 5828                            0.0
# 5327                            0.0
# 4810                            0.0
# ...                             ...
# 5734                            0.0
# 5191                            0.0
# 5390                            0.0
# 860                             0.0
# 7270                            0.0
#
# [6392 rows x 51 columns]

# %% [markdown]
# # Processing

# %% [markdown]
# ## Regression Metric Function

# %%
# Create a function to take the true and predicted values
def evaluate_regression(model, X_train,y_train, X_test, y_test): 
    """Evaluates a scikit learn regression model using r-squared and RMSE"""
    
    ## Training Data
    y_pred_train = model.predict(X_train)
    r2_train = metrics.r2_score(y_train, y_pred_train)
    rmse_train = metrics.mean_squared_error(y_train, y_pred_train, 
                                            squared=False)
    mse_train = mean_squared_error(y_train, y_pred_train)
    mae_train = mean_absolute_error(y_train, y_pred_train)
    
    print(f"Training Data:\nMAE: {mae_train:,.2f} \nMSE: {mse_train:,.2f} \nRMSE: {rmse_train:,.2f} \nR2: {r2_train:.2f}")
        
    print("\n")
    ## Test Data
    y_pred_test = model.predict(X_test)
    r2_test = metrics.r2_score(y_test, y_pred_test)
    rmse_test = metrics.mean_squared_error(y_test, y_pred_test, 
                                            squared=False)
    
    mse_test = mean_squared_error(y_test, y_pred_test)
    mae_test = mean_absolute_error(y_test, y_pred_test)
    
    print(f"Test Data:\nMAE= {mae_test:,.2f} \nMSE: {mse_test:,.2f} \nRMSE: {rmse_test:,.2f} \nR2: {r2_test:.2f}")

# %%
def plot_residuals(model,X_test_df, y_test,figsize=(12,5)):
  
    ## Make predictions and calculate residuals
    y_pred = model.predict(X_test_df)
    resid = y_test - y_pred
    
    fig, axes = plt.subplots(ncols=2,figsize=figsize)
    
    ## Normality 
    sm.graphics.qqplot(resid, line='45',fit=True,ax=axes[0]);
    axes[0].set_title('Normality', fontsize = 15, weight='bold')
    ## Homoscedascity
    ax = axes[1]
    ax.scatter(y_pred, resid, edgecolor='white',lw=0.5)
    ax.axhline(0,zorder=0)
    ax.set(ylabel='Residuals',xlabel='Predicted Value')
    axes[1].set_title('Homoscedasticity', fontsize = 15, weight='bold')
    plt.tight_layout()

# %% [markdown]
# ## Linear regression model

# %% [markdown]
# ### Checking Normality and Homoscedasticity

# %%
## concatenating training data into plot_df
plot_df = pd.concat([X_train_df,y_train],axis=1)
plot_df
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Item_Fat_Content_Low Fat  \
# 4776       16.350         0.029565  256.4646                       1.0
# 7510       15.250         0.000000  179.7660                       0.0
# 5828       12.350         0.158716  157.2946                       0.0
# 5327        7.975         0.014628   82.3250                       1.0
# 4810       19.350         0.016645  120.9098                       1.0
# ...           ...              ...       ...                       ...
# 5734        9.395         0.286345  139.1838                       0.0
# 5191       15.600         0.117575   75.6670                       1.0
# 5390       17.600         0.018944  237.3590                       1.0
# 860        20.350         0.054363  117.9466                       1.0
# 7270       16.350         0.016993   95.7410                       1.0
#
#       Item_Fat_Content_Regular  Item_Type_Baking Goods  Item_Type_Breads  \
# 4776                       0.0                     0.0               0.0
# 7510                       1.0                     0.0               0.0
# 5828                       1.0                     0.0               0.0
# 5327                       0.0                     1.0               0.0
# 4810                       0.0                     0.0               0.0
# ...                        ...                     ...               ...
# 5734                       1.0                     0.0               0.0
# 5191                       0.0                     0.0               0.0
# 5390                       0.0                     0.0               0.0
# 860                        0.0                     0.0               0.0
# 7270                       0.0                     0.0               0.0
#
#       Item_Type_Breakfast  Item_Type_Canned  Item_Type_Dairy  ...  \
# 4776                  0.0               0.0              0.0  ...
# 7510                  0.0               0.0              0.0  ...
# 5828                  0.0               0.0              0.0  ...
# 5327                  0.0               0.0              0.0  ...
# 4810                  0.0               0.0              0.0  ...
# ...                   ...               ...              ...  ...
# 5734                  0.0               0.0              0.0  ...
# 5191                  0.0               0.0              0.0  ...
# 5390                  0.0               0.0              0.0  ...
# 860                   0.0               0.0              0.0  ...
# 7270                  0.0               0.0              0.0  ...
#
#       Outlet_Size_Medium  Outlet_Size_Small  Outlet_Location_Type_Tier 1  \
# 4776                 1.0                0.0                          0.0
# 7510                 1.0                0.0                          0.0
# 5828                 1.0                0.0                          1.0
# 5327                 0.0                1.0                          0.0
# 4810                 0.0                0.0                          0.0
# ...                  ...                ...                          ...
# 5734                 0.0                0.0                          0.0
# 5191                 0.0                0.0                          0.0
# 5390                 0.0                0.0                          0.0
# 860                  0.0                0.0                          0.0
# 7270                 0.0                1.0                          1.0
#
#       Outlet_Location_Type_Tier 2  Outlet_Location_Type_Tier 3  \
# 4776                          0.0                          1.0
# 7510                          0.0                          1.0
# 5828                          0.0                          0.0
# 5327                          1.0                          0.0
# 4810                          1.0                          0.0
# ...                           ...                          ...
# 5734                          0.0                          1.0
# 5191                          1.0                          0.0
# 5390                          1.0                          0.0
# 860                           1.0                          0.0
# 7270                          0.0                          0.0
#
#       Outlet_Type_Grocery Store  Outlet_Type_Supermarket Type1  \
# 4776                        0.0                            0.0
# 7510                        0.0                            0.0
# 5828                        0.0                            1.0
# 5327                        0.0                            1.0
# 4810                        0.0                            1.0
# ...                         ...                            ...
# 5734                        1.0                            0.0
# 5191                        0.0                            1.0
# 5390                        0.0                            1.0
# 860                         0.0                            1.0
# 7270                        0.0                            1.0
#
#       Outlet_Type_Supermarket Type2  Outlet_Type_Supermarket Type3  \
# 4776                            1.0                            0.0
# 7510                            1.0                            0.0
# 5828                            0.0                            0.0
# 5327                            0.0                            0.0
# 4810                            0.0                            0.0
# ...                             ...                            ...
# 5734                            0.0                            0.0
# 5191                            0.0                            0.0
# 5390                            0.0                            0.0
# 860                             0.0                            0.0
# 7270                            0.0                            0.0
#
#       Item_Outlet_Sales
# 4776           515.3292
# 7510          3056.0220
# 5828          1577.9460
# 5327          1331.6000
# 4810          1687.1372
# ...                 ...
# 5734           280.9676
# 5191          1301.6390
# 5390          6145.3340
# 860           1649.8524
# 7270           965.4100
#
# [6392 rows x 52 columns]

# %%
## fitting a linear regression model
lin_reg = LinearRegression()
lin_reg.fit(X_train_df, y_train)
evaluate_regression(lin_reg, X_train_df, y_train, X_test_df,y_test)
# Out:
# Training Data:
# MAE: 847.13
# MSE: 1,297,558.14
# RMSE: 1,139.10
# R2: 0.56
#
#
# Test Data:
# MAE= 804.12
# MSE: 1,194,349.72
# RMSE: 1,092.86
# R2: 0.57

# %% [markdown]
# The R2 score was too low, let's check if we have some outliers.

# %%
plot_residuals(lin_reg, X_test_df,y_test)

# %% [markdown]
# Looking at our plots above, we can see that there are some outliers (a right tail) and there is no homoscedasticity (equal variance). Let's remove these outliers and check if we can improve R2 score.

# %% [markdown]
# ### Removing Outliers

# %%
# create a function to find outliers 

from scipy import stats
def find_outliers(data, verbose=True):
    outliers = np.abs(stats.zscore(data))>3
    
    if verbose:
        print(f"- {outliers.sum()} outliers found in {data.name} using Z-Scores.")
    return outliers

# %%
df_sales
# Out:
#       Item_Identifier Item_Fat_Content  Item_Visibility           Item_Type  \
# 0               FDA15          Low Fat         0.016047               Dairy
# 7               FDA15          Low Fat         0.016055               Dairy
# 14              FDA15          Low Fat         0.016019               Dairy
# 21              FDA15          Low Fat         0.016088               Dairy
# 28              FDA15          Low Fat         0.026818               Dairy
# ...               ...              ...              ...                 ...
# 41522           NCF55          Low Fat         0.021666           Household
# 41525           NCW30          Low Fat         0.011072           Household
# 41527           NCW30          Low Fat         0.011008           Household
# 41529           NCW05          Low Fat         0.148303  Health and Hygiene
# 41531           NCW05          Low Fat         0.148373  Health and Hygiene
#
#        Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0      249.8092            OUT049                       1999      Medium
# 7      250.2092            OUT045                       2002     Unknown
# 14     248.5092            OUT035                       2004       Small
# 21     249.6092            OUT018                       2009      Medium
# 28     248.9092            OUT010                       1998     Unknown
# ...         ...               ...                        ...         ...
# 41522   33.3874            OUT046                       1997       Small
# 41525  257.8962            OUT017                       2007     Unknown
# 41527  259.5962            OUT035                       2004       Small
# 41529  108.3938            OUT049                       1999      Medium
# 41531  108.8938            OUT045                       2002     Unknown
#
#       Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0                   Tier 1  Supermarket Type1          3735.1380
# 7                   Tier 2  Supermarket Type1          5976.2208
# 14                  Tier 2  Supermarket Type1          6474.2392
# 21                  Tier 3  Supermarket Type2          5976.2208
# 28                  Tier 3      Grocery Store           498.0184
# ...                    ...                ...                ...
# 41522               Tier 1  Supermarket Type1          1235.0590
# 41525               Tier 2  Supermarket Type1          4402.9354
# 41527               Tier 2  Supermarket Type1          2848.9582
# 41529               Tier 1  Supermarket Type1          2787.0388
# 41531               Tier 2  Supermarket Type1          3644.5892
#
#        Item_Weight_y
# 0              9.300
# 7              9.300
# 14             9.300
# 21             9.300
# 28             9.300
# ...              ...
# 41522          6.675
# 41525          5.210
# 41527          5.210
# 41529         20.250
# 41531         20.250
#
# [8519 rows x 12 columns]

# %%
num_sel(df_sales)
# Out:
# ['Item_Visibility',
#  'Item_MRP',
#  'Outlet_Establishment_Year',
#  'Item_Outlet_Sales',
#  'Item_Weight_y']

# %%
## save a dictionary of the T/F outlier index for each feature in outleir_cols
outlier_cols = ['Item_Visibility', 'Item_MRP','Item_Outlet_Sales', 'Item_Weight_y']

outliers = {}
for col in outlier_cols:
    outliers_col = find_outliers(df_sales[col])
    outliers[col] = outliers_col
# Out:
# - 95 outliers found in Item_Visibility using Z-Scores.
# - 0 outliers found in Item_MRP using Z-Scores.
# - 90 outliers found in Item_Outlet_Sales using Z-Scores.
# - 0 outliers found in Item_Weight_y using Z-Scores.

# %%
# Make new df_clean copy of df
df_clean = df_sales.copy()
## loop through dictionary to remove outliers
for col, idx_outliers in outliers.items():
    df_clean = df_clean[~idx_outliers]
df_clean
# Out:
#       Item_Identifier Item_Fat_Content  Item_Visibility           Item_Type  \
# 0               FDA15          Low Fat         0.016047               Dairy
# 7               FDA15          Low Fat         0.016055               Dairy
# 14              FDA15          Low Fat         0.016019               Dairy
# 21              FDA15          Low Fat         0.016088               Dairy
# 28              FDA15          Low Fat         0.026818               Dairy
# ...               ...              ...              ...                 ...
# 41522           NCF55          Low Fat         0.021666           Household
# 41525           NCW30          Low Fat         0.011072           Household
# 41527           NCW30          Low Fat         0.011008           Household
# 41529           NCW05          Low Fat         0.148303  Health and Hygiene
# 41531           NCW05          Low Fat         0.148373  Health and Hygiene
#
#        Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0      249.8092            OUT049                       1999      Medium
# 7      250.2092            OUT045                       2002     Unknown
# 14     248.5092            OUT035                       2004       Small
# 21     249.6092            OUT018                       2009      Medium
# 28     248.9092            OUT010                       1998     Unknown
# ...         ...               ...                        ...         ...
# 41522   33.3874            OUT046                       1997       Small
# 41525  257.8962            OUT017                       2007     Unknown
# 41527  259.5962            OUT035                       2004       Small
# 41529  108.3938            OUT049                       1999      Medium
# 41531  108.8938            OUT045                       2002     Unknown
#
#       Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0                   Tier 1  Supermarket Type1          3735.1380
# 7                   Tier 2  Supermarket Type1          5976.2208
# 14                  Tier 2  Supermarket Type1          6474.2392
# 21                  Tier 3  Supermarket Type2          5976.2208
# 28                  Tier 3      Grocery Store           498.0184
# ...                    ...                ...                ...
# 41522               Tier 1  Supermarket Type1          1235.0590
# 41525               Tier 2  Supermarket Type1          4402.9354
# 41527               Tier 2  Supermarket Type1          2848.9582
# 41529               Tier 1  Supermarket Type1          2787.0388
# 41531               Tier 2  Supermarket Type1          3644.5892
#
#        Item_Weight_y
# 0              9.300
# 7              9.300
# 14             9.300
# 21             9.300
# 28             9.300
# ...              ...
# 41522          6.675
# 41525          5.210
# 41527          5.210
# 41529         20.250
# 41531         20.250
#
# [8334 rows x 12 columns]

# %% [markdown]
# #### Repeat Linear Regression with outliers removed (Z_scores)

# %%
## Get new x,y for df_clean
# matrix  - drop columns 'Item_Identifier' (this feature will not make any contribution in model building. There are too many unique values 
X = df_clean.drop(columns=['Item_Outlet_Sales', 'Item_Identifier'])

# target
y = df_clean['Item_Outlet_Sales']

# Perform a train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Fit on Train
preprocessor.fit(X_train)
# get feature names 
feature_names = preprocessor.get_feature_names_out()
# remake X_train
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                           columns = feature_names, index = X_train.index)

# remake X_test
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                           columns = feature_names, index = X_test.index)

# check
print('size of X_train_df(75% of df_clean)')
print(len(X_train_df))
print('size of df_clean')
print(len(df_clean))
# Out:
# size of X_train_df(75% of df_clean)
# 6250
# size of df_clean
# 8334

# %%
## fitting a linear regression model with outliers removed 
lin_reg = LinearRegression()
lin_reg.fit(X_train_df, y_train)
evaluate_regression(lin_reg, X_train_df, y_train, X_test_df,y_test)
# Out:
# Training Data:
# MAE: 800.14
# MSE: 1,104,727.00
# RMSE: 1,051.06
# R2: 0.56
#
#
# Test Data:
# MAE= 794.38
# MSE: 1,098,107.20
# RMSE: 1,047.91
# R2: 0.55

# %% [markdown]
# The R2 score didn't improve afther remove outliers.

# %% [markdown]
# ### Extract the coefficients that your model determined.

# %%
## Checking the number of coeffs matches the # of feature names
print(len(lin_reg.coef_))
len(feature_names)
# Out:
# 43
# 43

# %%
## Saving the coefficients
coeffs = pd.Series(lin_reg.coef_, index= feature_names)
coeffs
# Out:
# Item_Visibility                   -140.884596
# Item_MRP                            14.527693
# Outlet_Establishment_Year          -10.260968
# Item_Weight_y                       -0.648702
# Item_Fat_Content_Low Fat           -16.046061
# Item_Fat_Content_Regular            16.046061
# Item_Type_Baking Goods             -10.859457
# Item_Type_Breads                    31.811506
# Item_Type_Breakfast                -35.753257
# Item_Type_Canned                    19.031933
# Item_Type_Dairy                    -64.178502
# Item_Type_Frozen Foods             -20.605615
# Item_Type_Fruits and Vegetables     25.818588
# Item_Type_Hard Drinks               14.699647
# Item_Type_Health and Hygiene        -9.141436
# Item_Type_Household                -72.583125
# Item_Type_Meat                       4.592878
# Item_Type_Others                    -1.287591
# Item_Type_Seafood                  280.163119
# Item_Type_Snack Foods              -52.504334
# Item_Type_Soft Drinks              -80.807694
# Item_Type_Starchy Foods            -28.396660
# Outlet_Identifier_OUT010          -421.441386
# Outlet_Identifier_OUT013           -47.576084
# Outlet_Identifier_OUT017           198.576324
# Outlet_Identifier_OUT018           -75.495286
# Outlet_Identifier_OUT019          -438.070735
# Outlet_Identifier_OUT027           538.247064
# Outlet_Identifier_OUT035            41.428633
# Outlet_Identifier_OUT045           -15.763961
# Outlet_Identifier_OUT046           296.827887
# Outlet_Identifier_OUT049           -76.732455
# Outlet_Size_High                   -47.576084
# Outlet_Size_Medium                 386.019323
# Outlet_Size_Small                  -99.814215
# Outlet_Size_Unknown               -238.629023
# Outlet_Location_Type_Tier 1       -217.975303
# Outlet_Location_Type_Tier 2        224.240996
# Outlet_Location_Type_Tier 3         -6.265692
# Outlet_Type_Grocery Store         -859.512121
# Outlet_Type_Supermarket Type1      396.760343
# Outlet_Type_Supermarket Type2      -75.495286
# Outlet_Type_Supermarket Type3      538.247064
# dtype: float64

# %%
# use .loc to add the intercept to the series
#coeffs.loc['intercept'] = lin_reg.intercept_
coeffs
# Out:
# Item_Visibility                   -140.884596
# Item_MRP                            14.527693
# Outlet_Establishment_Year          -10.260968
# Item_Weight_y                       -0.648702
# Item_Fat_Content_Low Fat           -16.046061
# Item_Fat_Content_Regular            16.046061
# Item_Type_Baking Goods             -10.859457
# Item_Type_Breads                    31.811506
# Item_Type_Breakfast                -35.753257
# Item_Type_Canned                    19.031933
# Item_Type_Dairy                    -64.178502
# Item_Type_Frozen Foods             -20.605615
# Item_Type_Fruits and Vegetables     25.818588
# Item_Type_Hard Drinks               14.699647
# Item_Type_Health and Hygiene        -9.141436
# Item_Type_Household                -72.583125
# Item_Type_Meat                       4.592878
# Item_Type_Others                    -1.287591
# Item_Type_Seafood                  280.163119
# Item_Type_Snack Foods              -52.504334
# Item_Type_Soft Drinks              -80.807694
# Item_Type_Starchy Foods            -28.396660
# Outlet_Identifier_OUT010          -421.441386
# Outlet_Identifier_OUT013           -47.576084
# Outlet_Identifier_OUT017           198.576324
# Outlet_Identifier_OUT018           -75.495286
# Outlet_Identifier_OUT019          -438.070735
# Outlet_Identifier_OUT027           538.247064
# Outlet_Identifier_OUT035            41.428633
# Outlet_Identifier_OUT045           -15.763961
# Outlet_Identifier_OUT046           296.827887
# Outlet_Identifier_OUT049           -76.732455
# Outlet_Size_High                   -47.576084
# Outlet_Size_Medium                 386.019323
# Outlet_Size_Small                  -99.814215
# Outlet_Size_Unknown               -238.629023
# Outlet_Location_Type_Tier 1       -217.975303
# Outlet_Location_Type_Tier 2        224.240996
# Outlet_Location_Type_Tier 3         -6.265692
# Outlet_Type_Grocery Store         -859.512121
# Outlet_Type_Supermarket Type1      396.760343
# Outlet_Type_Supermarket Type2      -75.495286
# Outlet_Type_Supermarket Type3      538.247064
# dtype: float64

# %% [markdown]
# ### Visualizing Coefficients

# %%
# function to get coefficients
def annotate_hbars(ax, ha='left',va='center',size=12,  xytext=(4,0),
                  textcoords='offset points'):
    for bar in ax.patches:
    
        ## calculate center of bar
        bar_ax = bar.get_y() + bar.get_height()/2
        ## get the value to annotate
        val = bar.get_width()
        if val < 0:
            val_pos = 0
        else:
            val_pos = val
        # ha and va stand for the horizontal and vertical alignment
        ax.annotate(f"{val:.3f}", (val_pos,bar_ax), ha=ha,va=va,size=size,
                        xytext=xytext, textcoords=textcoords)

# %%
# function to plot
def plot_coeffs(coeffs, top_n=None,  figsize=(10,5), intercept=False,  intercept_name = "intercept", color = None, annotate=False, ha='left',va='center', size=12, xytext=(4,0), textcoords='offset points'):
  """Plots the top_n coefficients from a Series, with optional annotations."""
# Drop intercept if intercept=False and 
  if (intercept==False) & ( intercept_name in coeffs.index):
    coeffs = coeffs.drop(intercept_name)
  if top_n==None:
    ## sort all features and set title
    plot_vals = coeffs#.sort_values()
    title = "All Coefficients - Ranked by Magnitude"
  else:
    ## rank the coeffs and select the top_n
    coeff_rank = coeffs.abs().rank().sort_values(ascending=False)
    top_n_features = coeff_rank.head(top_n)
## sort features and keep top_n and set title
    plot_vals = coeffs.loc[top_n_features.index].sort_values()

       
    ## plotting top N importances
    ax = plot_vals.plot(kind='barh', figsize=figsize)
    ax.set_title(f"Linear Regression Top {top_n} Largest Coefficients", fontsize = 15, fontweight='bold')
    ax.set_xlabel('Coefficient', fontsize = 15, fontweight='bold') 
    ax.set_ylabel('Feature Names', fontsize = 15, fontweight='bold')
    ax.set_facecolor("lightgray")
    ax.axvline(0, color='k')
    ## annotating bar values 
  if annotate==True:
    annotate_hbars(ax, ha=ha,va=va,size=size,xytext=xytext,
                       textcoords=textcoords)
    return ax

# %%
def plot_coeffs_color(coeffs, top_n=None,  figsize=(8,6), color_dict= {},
                   plot_kws = {}):
    """Plots series of coefficient
    Args:
        ceoffs (pands Series): importance values to plot
        top_n (int): The # of features to display (Default=None).
                         If None, display all.
                        otherwise display top_n most important
                         
        figsize (tuple): figsize tuple for .plot
        color_dict (dict): dict with index values as keys with color to use as vals
                            Uses series.index.map(color_dict).
        plot_kws (dict): additional keyword args accepted by panda's .plot
         
        Returns:
        Axis: matplotlib axis
        """
    # sorting with asc=false for correct order of bars
    if top_n is None:
        ## sort all features and set title
        plot_vals = coeffs.sort_values()
        title = "All Coefficients"
    else:
        ## rank the coeffs and select the top_n
        coeff_rank = coeffs.abs().rank().sort_values(ascending=False)
        top_n_features = coeff_rank.head(top_n)
        plot_vals = coeffs.loc[top_n_features.index].sort_values()
        ## sort features and keep top_n and set title
        title = f"Top {top_n} Largest Coefficients" 
         ## plotting top N importances
    if color_dict is not None:
        ## Getting color list and saving to plot_kws
        colors = plot_vals.index.map(color_dict)
        plot_kws = plot_kws.update({'color':colors})
    
    
    ax = plot_vals.plot(kind='barh', figsize=figsize,**plot_kws)
    ax.set(xlabel='Coefficient',
            ylabel='Feature Names',
            title=title)
    
    ## return ax in case want to continue to update/modify figure
    return ax

# %%
## color -coding top 5 bars
decrease_coeff = coeffs.sort_values(ascending=True).head(5).index
decrease_coeff
# Out:
# Index(['Outlet_Type_Grocery Store', 'Outlet_Identifier_OUT019',
#        'Outlet_Identifier_OUT010', 'Outlet_Size_Unknown',
#        'Outlet_Location_Type_Tier 1'],
#       dtype='object')

# %%
## create a dictionary of each feature and its color
colors_dict = {}
for col in coeffs.index:
    if col in decrease_coeff:
        colors_dict[col] = 'red'    
    else:
        colors_dict[col] = '#006ba4'
colors_dict
# Out:
# {'Item_Visibility': '#006ba4',
#  'Item_MRP': '#006ba4',
#  'Outlet_Establishment_Year': '#006ba4',
#  'Item_Weight_y': '#006ba4',
#  'Item_Fat_Content_Low Fat': '#006ba4',
#  'Item_Fat_Content_Regular': '#006ba4',
#  'Item_Type_Baking Goods': '#006ba4',
#  'Item_Type_Breads': '#006ba4',
#  'Item_Type_Breakfast': '#006ba4',
#  'Item_Type_Canned': '#006ba4',
#  'Item_Type_Dairy': '#006ba4',
#  'Item_Type_Frozen Foods': '#006ba4',
#  'Item_Type_Fruits and Vegetables': '#006ba4',
#  'Item_Type_Hard Drinks': '#006ba4',
#  'Item_Type_Health and Hygiene': '#006ba4',
#  'Item_Type_Household': '#006ba4',
#  'Item_Type_Meat': '#006ba4',
#  'Item_Type_Others': '#006ba4',
#  'Item_Type_Seafood': '#006ba4',
#  'Item_Type_Snack Foods': '#006ba4',
#  'Item_Type_Soft Drinks': '#006ba4',
#  'Item_Type_Starchy Foods': '#006ba4',
#  'Outlet_Identifier_OUT010': 'red',
#  'Outlet_Identifier_OUT013': '#006ba4',
#  'Outlet_Identifier_OUT017': '#006ba4',
#  'Outlet_Identifier_OUT018': '#006ba4',
#  'Outlet_Identifier_OUT019': 'red',
#  'Outlet_Identifier_OUT027': '#006ba4',
#  'Outlet_Identifier_OUT035': '#006ba4',
#  'Outlet_Identifier_OUT045': '#006ba4',
#  'Outlet_Identifier_OUT046': '#006ba4',
#  'Outlet_Identifier_OUT049': '#006ba4',
#  'Outlet_Size_High': '#006ba4',
#  'Outlet_Size_Medium': '#006ba4',
#  'Outlet_Size_Small': '#006ba4',
#  'Outlet_Size_Unknown': 'red',
#  'Outlet_Location_Type_Tier 1': 'red',
#  'Outlet_Location_Type_Tier 2': '#006ba4',
#  'Outlet_Location_Type_Tier 3': '#006ba4',
#  'Outlet_Type_Grocery Store': 'red',
#  'Outlet_Type_Supermarket Type1': '#006ba4',
#  'Outlet_Type_Supermarket Type2': '#006ba4',
#  'Outlet_Type_Supermarket Type3': '#006ba4'}

# %%
ax= plot_coeffs(coeffs, top_n=10, annotate=True)
## How to put my colors_dict in patches??

# %%
## we can plot bars features that decrease in red : 
colors = coeffs.index.map(colors_dict)

# %%
coeff_rank = coeffs.abs().rank().sort_values(ascending=False)
top_n_features = coeff_rank.head(10)
plot_vals = coeffs.loc[top_n_features.index].sort_values()
colors = plot_vals.index.map(colors_dict)       
ax = plot_vals.plot(color=colors, kind = 'barh')
ax.set_title(f"Linear Regression To10 Largest Coefficients", fontsize = 15, fontweight='bold')
ax.set_xlabel('Coefficient', fontsize = 15, fontweight='bold') 
ax.set_ylabel('Feature Names', fontsize = 15, fontweight='bold')
ax.set_facecolor("lightgray")
ax.axvline(0, color='k')
annotate_hbars(ax, ha='left',va='center',size=12,xytext=(4,0),
                       textcoords='offset points')

# %% [markdown]
# ### Interpreting Model's Coefficients
#
# #### Coefficients that Positively Influence the predicted sales:
#
# Outlet_Location_Type_Tier 3: Being in the Location_Type_Tier 3 increases the predicted sales by 578.079.
#
# Outlet_Identifier_OUT027: Being the Outlet # OUT027 increases the predicted sales by 578.079.
#
# Outlet_Size_Medium: Being the Outlet of medium size increases the predicted sales by 412.835.
#
# Outlet_Type_Supermarket Type1: Being the Outlet of Supermarket Type1 increases the predicted sales by 343.800.
#
# Item_Type_Seafood: Sell seafood increase the predicted sales by 308.889
#
# #### Coefficients that Negatively Influencethe the predicted sales:
#
# Outlet_Type_Grocery Store: Being a Grocery store subtracted 779.810 from the predicted sales.
#
# Outlet_Identifier_OUT019: Being the Outlet # OUT019 decreases the predicted sales by 452.442.
#
# Item_Visibility: for every increase of 1 unit in visibility the  predicted sales will decrease 423.390.
#
# Outlet_Identifier_OUT010: Being the Outlet # OUT010 decreases the predicted sales by 327.368.
#
# Outlet_Establishment_Year_1998: if the store was established in 1998 decreases the predicted sales by 327.368

# %% [markdown]
# ## Randon Forest
#
# I will try without remove outliers

# %%
## Get new x,y for df_clean
# matrix  - drop columns 'Item_Identifier' (this feature will not make any contribution in model building. There are too many unique values 
X = df_sales.drop(columns=['Item_Outlet_Sales', 'Item_Identifier'])

# targetes
y = df_sales['Item_Outlet_Sales']

# Perform a train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Fit on Train
preprocessor.fit(X_train)
# get feature names 
feature_names = preprocessor.get_feature_names_out()
# remake X_train
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                           columns = feature_names, index = X_train.index)

# remake X_test
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                           columns = feature_names, index = X_test.index)

# check
print('size of X_train_df(75% of df_clean)')
print(len(X_train_df))
print('size of df_sales')
print(len(df_sales))
# Out:
# size of X_train_df(75% of df_clean)
# 6389
# size of df_sales
# 8519

# %%
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train_df,y_train)
evaluate_regression(rf, X_train_df, y_train, X_test_df, y_test)
# Out:
# Training Data:
# MAE: 292.58
# MSE: 178,942.32
# RMSE: 423.02
# R2: 0.94
#
#
# Test Data:
# MAE= 793.58
# MSE: 1,273,528.62
# RMSE: 1,128.51
# R2: 0.55

# %% [markdown]
# It is overfitting, we can try to tunne it

# %% [markdown]
# ### Tune RandomForest

# %%
rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
est_depths = [estimator.get_depth() for estimator in rf.estimators_]
max(est_depths)
# Out:
# 45

# %%
n_ests = list(range(2,46)) 
scores2 = pd.DataFrame(index=n_ests, columns=['Test Score', 'Train Score'])
for n in n_ests:
  rf_9_tunned = RandomForestRegressor(max_depth=n, random_state=42)
  tree_reg_pipe_rf = make_pipeline(preprocessor, rf_9_tunned)
  tree_reg_pipe_rf.fit(X_train_df,y_train)
  train_pred_tree_rf = tree_reg_pipe_rf.predict(X_train_df)
  test_pred_tree_rf = tree_reg_pipe_rf.predict(X_test_df)
  scores2.loc[n, 'Train Score'] = r2_score(y_train, train_pred_tree_rf)
  scores2.loc[n, 'Test Score'] = r2_score(y_test, test_pred_tree_rf)

# %%
scores2.sort_values(by='Test Score', ascending=False)
# Out:
#    Test Score Train Score
# 6    0.594034     0.62776
# 5    0.593981    0.613515
# 7    0.591325    0.646444
# 8    0.589415    0.669213
# 9    0.586835    0.695769
# 10   0.584414    0.724639
# 11   0.582274    0.754341
# 12    0.57842    0.783083
# 4    0.575636    0.596246
# 13   0.574278    0.810633
# 14   0.570057    0.835669
# 15   0.567694    0.857749
# 16   0.564025    0.876276
# 17   0.561837    0.891632
# 18     0.5591    0.903864
# 19   0.556813    0.913082
# 20   0.554192    0.920475
# 21   0.553425    0.926137
# 33   0.552943    0.938965
# 26   0.552916    0.937473
# 36   0.552766    0.939006
# 23   0.552732    0.932902
# 40   0.552573    0.938975
# 34   0.552558    0.938912
# 42   0.552429    0.938982
# 45   0.552425    0.938989
# 44   0.552403    0.938981
# 41   0.552395    0.938978
# 43   0.552394     0.93899
# 39   0.552286    0.939007
# 38   0.552278    0.939014
# 37   0.552241    0.939039
# 28    0.55207    0.938561
# 22   0.551959    0.930103
# 35   0.551755    0.938974
# 24   0.551655    0.935066
# 29   0.551649    0.938753
# 31   0.551461    0.939102
# 27   0.551293    0.938007
# 25   0.551131    0.936506
# 32   0.550678    0.938852
# 30   0.550602    0.938916
# 3    0.521038    0.534114
# 2    0.437122    0.452169

# %%
# The 'max_depth' with better Testing score was 5 
rf_6 = RandomForestRegressor(max_depth = 5, random_state = 42)
rf_6.fit(X_train_df, y_train)
evaluate_regression(rf_6, X_train_df, y_train, X_test_df,y_test)
# Out:
# Training Data:
# MAE: 745.83
# MSE: 1,133,540.89
# RMSE: 1,064.68
# R2: 0.61
#
#
# Test Data:
# MAE= 756.92
# MSE: 1,155,284.34
# RMSE: 1,074.84
# R2: 0.59

# %% [markdown]
# With max_depth= 6 we can see that in training datase R2 score is 59% that is better than default value 55%. But the score is not good, let's try tune the n_estimators.

# %%
# by default n_estimators': 100
# let's try another values:
n_ests = [250, 300, 350, 450]
scores2 = pd.DataFrame(index=n_ests, columns=['Test Score', 'Train Score'])
for n in n_ests:
  rf_6_tunned = RandomForestRegressor(max_depth=5, n_estimators=n)
  tree_reg_pipe_rf = make_pipeline(preprocessor, rf_6_tunned)
  tree_reg_pipe_rf.fit(X_train_df, y_train)
  train_pred_tree_rf = tree_reg_pipe_rf.predict(X_train_df)
  test_pred_tree_rf = tree_reg_pipe_rf.predict(X_test_df)
  scores2.loc[n, 'Train Score'] = r2_score(y_train, train_pred_tree_rf)
  scores2.loc[n, 'Test Score'] = r2_score(y_test, test_pred_tree_rf)

# %%
scores2.head()
# Out:
#     Test Score Train Score
# 250   0.593151    0.613225
# 300    0.59323    0.613275
# 350   0.593833    0.613437
# 450   0.593123     0.61342

# %%
plt.plot(scores2['Test Score'])
plt.xticks(n_ests);

# %% [markdown]
# We can see that we didn't improve the score of test dataset with tuning the n_estimators. It is 60%

# %% [markdown]
# ### Extracting Feature Importances

# %%
rf_6.feature_importances_
# Out:
# array([1.64993498e-03, 5.52012567e-01, 3.38004072e-02, 3.63711564e-03,
#        1.77571108e-06, 2.38688364e-06, 2.96729402e-05, 2.22048008e-04,
#        1.12419982e-05, 1.08352489e-05, 3.53579195e-05, 4.97374430e-06,
#        5.03800295e-05, 6.35871980e-05, 1.02009996e-04, 1.08643570e-04,
#        2.86288990e-05, 1.50287232e-06, 8.48276039e-08, 1.94524082e-04,
#        2.78699691e-05, 7.02500751e-05, 4.02786091e-06, 0.00000000e+00,
#        0.00000000e+00, 4.72609596e-05, 1.73853705e-06, 4.06417051e-02,
#        1.60556188e-04, 3.46410298e-05, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 8.41068206e-05, 4.36821821e-06, 2.48343936e-06,
#        2.69742004e-06, 0.00000000e+00, 2.47636391e-06, 3.18796148e-01,
#        3.45806639e-04, 3.35532005e-05, 4.77726321e-02])

# %%
## Checking the number of feature importances matches the # of columns
print(len(rf_6.feature_importances_))
print(len(X_train_df.columns))
len(rf_6.feature_importances_) == len(X_train_df.columns)
# Out:
# 43
# 43
# True

# %% [markdown]
# ### Saving the importances as a Pandas Series

# %%
## Saving the feature importances
importances = pd.Series(rf_6.feature_importances_, index= feature_names,
                       name='Feature Importance')
importances
# Out:
# Item_Visibility                    1.649935e-03
# Item_MRP                           5.520126e-01
# Outlet_Establishment_Year          3.380041e-02
# Item_Weight_y                      3.637116e-03
# Item_Fat_Content_Low Fat           1.775711e-06
# Item_Fat_Content_Regular           2.386884e-06
# Item_Type_Baking Goods             2.967294e-05
# Item_Type_Breads                   2.220480e-04
# Item_Type_Breakfast                1.124200e-05
# Item_Type_Canned                   1.083525e-05
# Item_Type_Dairy                    3.535792e-05
# Item_Type_Frozen Foods             4.973744e-06
# Item_Type_Fruits and Vegetables    5.038003e-05
# Item_Type_Hard Drinks              6.358720e-05
# Item_Type_Health and Hygiene       1.020100e-04
# Item_Type_Household                1.086436e-04
# Item_Type_Meat                     2.862890e-05
# Item_Type_Others                   1.502872e-06
# Item_Type_Seafood                  8.482760e-08
# Item_Type_Snack Foods              1.945241e-04
# Item_Type_Soft Drinks              2.786997e-05
# Item_Type_Starchy Foods            7.025008e-05
# Outlet_Identifier_OUT010           4.027861e-06
# Outlet_Identifier_OUT013           0.000000e+00
# Outlet_Identifier_OUT017           0.000000e+00
# Outlet_Identifier_OUT018           4.726096e-05
# Outlet_Identifier_OUT019           1.738537e-06
# Outlet_Identifier_OUT027           4.064171e-02
# Outlet_Identifier_OUT035           1.605562e-04
# Outlet_Identifier_OUT045           3.464103e-05
# Outlet_Identifier_OUT046           0.000000e+00
# Outlet_Identifier_OUT049           0.000000e+00
# Outlet_Size_High                   0.000000e+00
# Outlet_Size_Medium                 8.410682e-05
# Outlet_Size_Small                  4.368218e-06
# Outlet_Size_Unknown                2.483439e-06
# Outlet_Location_Type_Tier 1        2.697420e-06
# Outlet_Location_Type_Tier 2        0.000000e+00
# Outlet_Location_Type_Tier 3        2.476364e-06
# Outlet_Type_Grocery Store          3.187961e-01
# Outlet_Type_Supermarket Type1      3.458066e-04
# Outlet_Type_Supermarket Type2      3.355320e-05
# Outlet_Type_Supermarket Type3      4.777263e-02
# Name: Feature Importance, dtype: float64

# %%
## Saving the feature importances sorted from largest to smallest (ascending=False)
sorted_importance = importances.sort_values(ascending=True)
sorted_importance
# Out:
# Outlet_Size_High                   0.000000e+00
# Outlet_Location_Type_Tier 2        0.000000e+00
# Outlet_Identifier_OUT049           0.000000e+00
# Outlet_Identifier_OUT046           0.000000e+00
# Outlet_Identifier_OUT017           0.000000e+00
# Outlet_Identifier_OUT013           0.000000e+00
# Item_Type_Seafood                  8.482760e-08
# Item_Type_Others                   1.502872e-06
# Outlet_Identifier_OUT019           1.738537e-06
# Item_Fat_Content_Low Fat           1.775711e-06
# Item_Fat_Content_Regular           2.386884e-06
# Outlet_Location_Type_Tier 3        2.476364e-06
# Outlet_Size_Unknown                2.483439e-06
# Outlet_Location_Type_Tier 1        2.697420e-06
# Outlet_Identifier_OUT010           4.027861e-06
# Outlet_Size_Small                  4.368218e-06
# Item_Type_Frozen Foods             4.973744e-06
# Item_Type_Canned                   1.083525e-05
# Item_Type_Breakfast                1.124200e-05
# Item_Type_Soft Drinks              2.786997e-05
# Item_Type_Meat                     2.862890e-05
# Item_Type_Baking Goods             2.967294e-05
# Outlet_Type_Supermarket Type2      3.355320e-05
# Outlet_Identifier_OUT045           3.464103e-05
# Item_Type_Dairy                    3.535792e-05
# Outlet_Identifier_OUT018           4.726096e-05
# Item_Type_Fruits and Vegetables    5.038003e-05
# Item_Type_Hard Drinks              6.358720e-05
# Item_Type_Starchy Foods            7.025008e-05
# Outlet_Size_Medium                 8.410682e-05
# Item_Type_Health and Hygiene       1.020100e-04
# Item_Type_Household                1.086436e-04
# Outlet_Identifier_OUT035           1.605562e-04
# Item_Type_Snack Foods              1.945241e-04
# Item_Type_Breads                   2.220480e-04
# Outlet_Type_Supermarket Type1      3.458066e-04
# Item_Visibility                    1.649935e-03
# Item_Weight_y                      3.637116e-03
# Outlet_Establishment_Year          3.380041e-02
# Outlet_Identifier_OUT027           4.064171e-02
# Outlet_Type_Supermarket Type3      4.777263e-02
# Outlet_Type_Grocery Store          3.187961e-01
# Item_MRP                           5.520126e-01
# Name: Feature Importance, dtype: float64

# %%
## plotting top 10 importances
ax = sorted_importance.tail(10).plot(kind='barh',
                                    figsize=(7,5),
                                      )
ax.set(xlabel='Importance',
        ylabel='Feature Names',
        title='Top 10 Most Important Features');

# %% [markdown]
# or we can just use this function to get importance and plot

# %% [markdown]
# ### Remaking Our Model - Using Our Functions

# %%
# Create a custom function to get importances:
def get_importances(model, feature_names=None,name='Feature Importance',
                   sort=False, ascending=True):
    
    ## checking for feature names
    if feature_names == None:
        feature_names = model.feature_names_in_
        
    ## Saving the feature importances
    importances = pd.Series(model.feature_importances_, index= feature_names,
                           name=name)
    
    # sort importances
    if sort == True:
        importances = importances.sort_values(ascending=ascending)
        
    return importances

# %%
# Create a custom function to plot our importances:
def plot_importance(model, importances, top_n=None,  figsize=(10,5)):
    # sorting with asc=false for correct order of bars
    if top_n==None:
        ## sort all features and set title
        plot_vals = importances.sort_values()
        title = "All Features - Ranked by Importance"
    else:
        ## sort features and keep top_n and set title
        plot_vals = importances.sort_values().tail(top_n)
        
    ## plotting top N importances
    ax = plot_vals.plot(kind='barh', figsize=figsize)
  
    ax.set_title(f"{model} Top {top_n} Most Important Features", fontsize = 15, fontweight='bold')
    ax.set_xlabel('Importance', fontsize = 15, fontweight='bold') 
    ax.set_ylabel('Feature Names', fontsize = 15, fontweight='bold')
    ax.set_facecolor("lightgray")
    ## return ax in case want to continue to update/modify figure
    return ax

# %%
## fit random forest
rf_6 = RandomForestRegressor(max_depth = 5, random_state = 42)
rf_6.fit(X_train_df,y_train)
evaluate_regression(rf_6, X_train_df, y_train, X_test_df,y_test)
## Saving the feature importances
importances = get_importances(rf_6)
plot_importance('Radom Forest:',importances, top_n=10);
# Out:
# Training Data:
# MAE: 745.83
# MSE: 1,133,540.89
# RMSE: 1,064.68
# R2: 0.61
#
#
# Test Data:
# MAE= 756.92
# MSE: 1,155,284.34
# RMSE: 1,074.84
# R2: 0.59

# %%
## using the ax to get the fig
fig_ax = ax.get_figure()

# %% [markdown]
# ### Interpreting feature importances

# %% [markdown]
# Item_MRP (price), Outlet_Type_Grocery Store, Outlet_Identifier_OUT027, Outlet_Type_Supermarket Type3  and Outlet_Establishment_Year_1985 were the most important features used by our model. But we do not know the actual relationship between the feature and the target (Item_Outlest_Sales).

# %% [markdown]
# # Decision Tree Regressor

# %%
# instantiate a model
dec_tree = DecisionTreeRegressor(random_state = 42)

# put the model in pipeline
dec_tree_pipe = make_pipeline(preprocessor, dec_tree)

# fit the model on the training data
dec_tree_pipe.fit(X_train_df,y_train)
evaluate_regression(dec_tree_pipe, X_train_df, y_train, X_test_df,y_test)
# Out:
# Training Data:
# MAE: 0.00
# MSE: 0.00
# RMSE: 0.00
# R2: 1.00
#
#
# Test Data:
# MAE= 1,089.36
# MSE: 2,374,344.35
# RMSE: 1,540.89
# R2: 0.17

# %% [markdown]
# Decision Tree Model is overfit since the score of trainig is 100% and testing is only 17%. Let's try tune

# %% [markdown]
# ## Tune Decision tree model

# %%
dec_tree.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 42,
#  'splitter': 'best'}

# %%
# check max_depth
dec_tree.get_depth()
# Out:
# 38

# %%
# check how many leaf nodes
dec_tree.get_n_leaves()
# Out:
# 6296

# %%
# List of values to try for max_depth:
max_depth_range = list(range(2, 44)) # will try every value between 2 and 43
# List to store the score for each value of max_depth:
r2 = []
for depth in max_depth_range:
    dec_tree = DecisionTreeRegressor(max_depth = depth, 
                             random_state = 42)
    dec_tree.fit(X_train_df,y_train)
    score = dec_tree.score(X_test_df, y_test)
    r2.append(score)

# %%
# Visualize which max_depth leads to the highest r2 score
plt.plot(max_depth_range, r2)
plt.xlabel('max_depth')
plt.ylabel('R2');

# %% [markdown]
# It looks like the best score for the model is when the parameter max_depth is 5.

# %%
## fit dec tree with 5 max_depth
dec_tree_5 = DecisionTreeRegressor(max_depth = 5, random_state = 42)
dec_tree_5.fit(X_train_df,y_train)
evaluate_regression(dec_tree_5, X_train_df, y_train, X_test_df,y_test)
## Saving the feature importances
importances = get_importances(dec_tree_5)
plot_importance('Decision Tree:', importances, top_n=10);
# Out:
# Training Data:
# MAE: 752.07
# MSE: 1,151,629.88
# RMSE: 1,073.14
# R2: 0.61
#
#
# Test Data:
# MAE= 764.82
# MSE: 1,174,565.19
# RMSE: 1,083.77
# R2: 0.59

# %% [markdown]
# The result is very similar with Random Forest model. Now that  we now witch features are important we can try to drop some columns and check r2 score again.

# %% [markdown]
# # Plot the tree

# %%
example_tree =  rf_6.estimators_[0]
example_tree
# Out:
# DecisionTreeRegressor(max_depth=5, max_features=1.0, random_state=1608637542)

# %%
# Let's find out how deep it grew. Large trees can be very difficult to visualize in 1 graph.

example_tree.get_depth()
# Out:
# 5

# %%
# few layers
fig, ax = plt.subplots(figsize=(40,30))
plot_tree(example_tree, max_depth=5,filled=True,feature_names=feature_names,ax=ax,
         fontsize=10);

# %% [markdown]
# If we examine the decision pathway (which starts at the top-center of the image), we can see that the tree used Item_MRP (price) for many splits early on in the tree.

# %% [markdown]
# # Saving & Loading Models (joblib)

# %%
export = {'X_train':X_train_df,
         'y_train': y_train,
         'X_test':X_test_df,
          "y_test": y_test,
         'preprocessor':preprocessor,
         'Decisiontree': dec_tree_5, 'LinearRegression': lin_reg,
          'RandomForestRegressor':rf_6}

# %%
# making new folder with os
import os
folder = "Models/"
os.makedirs(folder, exist_ok=True)

# Confirm folder created
fname = folder+'Project1.joblib'
joblib.dump(export, fname)
# Out:
# ['Models/Project1.joblib']

# %%
loaded = joblib.load(fname)
loaded.keys()
# Out:
# dict_keys(['X_train', 'y_train', 'X_test', 'y_test', 'preprocessor', 'Decisiontree', 'LinearRegression', 'RandomForestRegressor'])

# %% [markdown]
# # Final model with top importance features.
#
#  Now that we now witch features are important we can try to drop some columns and check r2 score again.

# %%
df_ml.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
sorted_importance
# Out:
# Outlet_Size_High                   0.000000e+00
# Outlet_Location_Type_Tier 2        0.000000e+00
# Outlet_Identifier_OUT049           0.000000e+00
# Outlet_Identifier_OUT046           0.000000e+00
# Outlet_Identifier_OUT017           0.000000e+00
# Outlet_Identifier_OUT013           0.000000e+00
# Item_Type_Seafood                  8.482760e-08
# Item_Type_Others                   1.502872e-06
# Outlet_Identifier_OUT019           1.738537e-06
# Item_Fat_Content_Low Fat           1.775711e-06
# Item_Fat_Content_Regular           2.386884e-06
# Outlet_Location_Type_Tier 3        2.476364e-06
# Outlet_Size_Unknown                2.483439e-06
# Outlet_Location_Type_Tier 1        2.697420e-06
# Outlet_Identifier_OUT010           4.027861e-06
# Outlet_Size_Small                  4.368218e-06
# Item_Type_Frozen Foods             4.973744e-06
# Item_Type_Canned                   1.083525e-05
# Item_Type_Breakfast                1.124200e-05
# Item_Type_Soft Drinks              2.786997e-05
# Item_Type_Meat                     2.862890e-05
# Item_Type_Baking Goods             2.967294e-05
# Outlet_Type_Supermarket Type2      3.355320e-05
# Outlet_Identifier_OUT045           3.464103e-05
# Item_Type_Dairy                    3.535792e-05
# Outlet_Identifier_OUT018           4.726096e-05
# Item_Type_Fruits and Vegetables    5.038003e-05
# Item_Type_Hard Drinks              6.358720e-05
# Item_Type_Starchy Foods            7.025008e-05
# Outlet_Size_Medium                 8.410682e-05
# Item_Type_Health and Hygiene       1.020100e-04
# Item_Type_Household                1.086436e-04
# Outlet_Identifier_OUT035           1.605562e-04
# Item_Type_Snack Foods              1.945241e-04
# Item_Type_Breads                   2.220480e-04
# Outlet_Type_Supermarket Type1      3.458066e-04
# Item_Visibility                    1.649935e-03
# Item_Weight_y                      3.637116e-03
# Outlet_Establishment_Year          3.380041e-02
# Outlet_Identifier_OUT027           4.064171e-02
# Outlet_Type_Supermarket Type3      4.777263e-02
# Outlet_Type_Grocery Store          3.187961e-01
# Item_MRP                           5.520126e-01
# Name: Feature Importance, dtype: float64

# %%
# matrix  - drop columns features that will not make any contribution in model building
X = df_ml.drop(columns=['Item_Outlet_Sales', 'Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Outlet_Location_Type'])

# target
y = df_ml['Item_Outlet_Sales']

# Perform a train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)


X_train.head()
# Out:
#       Item_Visibility     Item_Type  Item_MRP Outlet_Identifier  \
# 4776         0.029565     Household  256.4646            OUT018
# 7510         0.000000   Snack Foods  179.7660            OUT018
# 5828         0.158716          Meat  157.2946            OUT049
# 5327         0.014628  Baking Goods   82.3250            OUT035
# 4810         0.016645  Frozen Foods  120.9098            OUT045
#
#      Outlet_Establishment_Year Outlet_Size        Outlet_Type
# 4776                      2009      Medium  Supermarket Type2
# 7510                      2009      Medium  Supermarket Type2
# 5828                      1999      Medium  Supermarket Type1
# 5327                      2004       Small  Supermarket Type1
# 4810                      2002         NaN  Supermarket Type1

# %%
# Perform a train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Fit on Train
preprocessor.fit(X_train)
# get feature names 
feature_names = preprocessor.get_feature_names_out()
# remake X_train
X_train_df_top = pd.DataFrame(preprocessor.transform(X_train),
                           columns = feature_names, index = X_train.index)

# remake X_test
X_test_df_top = pd.DataFrame(preprocessor.transform(X_test),
                           columns = feature_names, index = X_test.index)

# %%
# let's use randomforest with max_deph=5 
rf_6 = RandomForestRegressor(max_depth = 5, random_state = 42)
rf_6.fit(X_train_df_top, y_train)
evaluate_regression(rf_6, X_train_df_top, y_train, X_test_df_top,y_test)
# Out:
# Training Data:
# MAE: 755.52
# MSE: 1,152,668.03
# RMSE: 1,073.62
# R2: 0.61
#
#
# Test Data:
# MAE= 728.44
# MSE: 1,096,163.60
# RMSE: 1,046.98
# R2: 0.60

# %% [markdown]
# We improve only 1%!

# %% [markdown]
# # Model Comparison
#
# #### Compare the performance of models based on R2.
# With the linear regression model, the R2 score in the training dataset was 56%, with the decision tree and random forest model after tunning were 59%.
#
# These scores can be interpreted as saying that the linear regression model can account for about 56% of the variation in y_test using the features in X_test. The decision tree and random forest model can account for about 59% .
#
# #### Compare the performance of models based on MSE.
# A lower MSE is better as we want to reduce the size of errors, especially large errors!
#
# The mean of the target is 2095.231046 and if we check MSE in all models were:
#
# 1 -linear regression was MSE: 1,198,492.82,
#
# 2 - decision tree regressor was 1,057.44
#
# 3 - random forest: 1,046.96
#
# The MSE was lower with random forest regression but was too far from the mean target and any model had a score higher than 60%.
